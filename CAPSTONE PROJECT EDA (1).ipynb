# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("All_Tables_data.csv")

# %%
df.head()
# Out:
#                         Address           City            StateCode Country  \
# 0    MADHURAWADA, VISAKHAPATNAM  VISAKHAPATNAM  AD - Andhra Pradesh   India
# 1       INNER RING ROAD, GUNTUR         GUNTUR  AD - Andhra Pradesh   India
# 2          KORLAGUNTA, TIRUPATI       TIRUPATI  AD - Andhra Pradesh   India
# 3  NEW JOHRAPURAM RAOD, KURNOOL        KURNOOL  AD - Andhra Pradesh   India
# 4       GEETA NAGAR, VIJAYAWADA     VIJAYAWADA  AD - Andhra Pradesh   India
#
#   RentalPrice  Deposit    Bed  Bath      Area PetsAllowed Washer/Dryer   AC  \
# 0      11,999    59995  3 Bds  3 Ba  1800 ft2         YES          YES  YES
# 1       8,000    80000  2 Bds  2 Ba  1050 ft2          NO           NO   NO
# 2       4,000    40000  1 Bds  1 Ba   100 ft2          NO           NO   NO
# 3       4,500    45000  1 Bds  1 Ba   800 ft2          NO           NO   NO
# 4       3,200    32000  2 Bds  1 Ba  2500 ft2         YES          YES  YES
#
# ...

# %%
print(df.shape)
# Out:
# (5165, 18)

# %%
df.tail()
# Out:
#                             Address          City       StateCode Country  \
# 5160        KALYAN NAGAR, HYDERABAD     HYDERABAD  TS - Telangana   India
# 5161         LANGAR HOUZ, HYDERABAD     HYDERABAD  TS - Telangana   India
# 5162  TARNAKA CHINTAL, SECUNDERABAD  SECUNDERABAD  TS - Telangana   India
# 5163            MADHAPUR, HYDERABAD     HYDERABAD  TS - Telangana   India
# 5164          DAMMAIGUDA, HYDERABAD     HYDERABAD  TS - Telangana   India
#
#      RentalPrice   Deposit    Bed  Bath      Area PetsAllowed Washer/Dryer  \
# 5160       5,000     50000  2 Bds  2 Ba   173 ft2          NO           NO
# 5161      18,500     92500  1 Bds  2 Ba   700 ft2          NO           NO
# 5162       2,500     25000  2 Bds  2 Ba  1200 ft2          NO           NO
# 5163      25,000    125000  2 Bds  2 Ba   800 ft2          NO           NO
# 5164   52,00,000  26000000  3 Bds  3 Ba  1000 ft2          NO           NO
#
#       AC Parking Fireplace Dishwasher Hardwoodfloors Roofdeck Storage
# ...

# %%
df.dtypes
# Out:
# Address           object
# City              object
# StateCode         object
# Country           object
# RentalPrice       object
# Deposit            int64
# Bed               object
# Bath              object
# Area              object
# PetsAllowed       object
# Washer/Dryer      object
# AC                object
# Parking           object
# Fireplace         object
# Dishwasher        object
# Hardwoodfloors    object
# Roofdeck          object
# Storage           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Address           0
# City              0
# StateCode         0
# Country           0
# RentalPrice       0
# Deposit           0
# Bed               0
# Bath              0
# Area              0
# PetsAllowed       0
# Washer/Dryer      0
# AC                0
# Parking           0
# Fireplace         0
# Dishwasher        0
# Hardwoodfloors    0
# Roofdeck          0
# Storage           0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# DATA VISUALIZATION

# %%
df.columns
# Out:
# Index(['Address', 'City', 'StateCode', 'Country', 'RentalPrice', 'Deposit',
#        'Bed', 'Bath', 'Area', 'PetsAllowed', 'Washer/Dryer', 'AC', 'Parking',
#        'Fireplace', 'Dishwasher', 'Hardwoodfloors', 'Roofdeck', 'Storage'],
#       dtype='object')

# %%
sns.countplot(df['City'])
plt.show()

# %%
sns.countplot(df['Country'])
plt.show()

# %%
sns.countplot(df['RentalPrice'])
plt.show()

# %%
sns.countplot(df['Deposit'])
plt.show()

# %%
sns.countplot(df['Area'])
plt.show()

# %%
sns.countplot(df['Parking'])
plt.show()

# %%
sns.countplot(df['Fireplace'])
plt.show()

# %%
sns.countplot(df['Dishwasher'])
plt.show()

# %%
sns.countplot(df['Hardwoodfloors'])
plt.show()

# %%
sns.countplot(df['Roofdeck'])
plt.show()

# %%
sns.countplot(df['Storage'])
plt.show()

# %%
df.plot(kind ='box',subplots = True,layout =(4,4))
plt.tight_layout()

# %%
df.hist(figsize=(10,10))
plt.tight_layout()

# %%
sns.pairplot(df)

# %%
df.skew()
# Out:
# Deposit    16.975546
# dtype: float64
